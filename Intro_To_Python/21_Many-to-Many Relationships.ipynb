# %%
import json
import sqlite3

conn = sqlite3.connect('rosterdb.sqlite')
cur = conn.cursor()

# Do some setup
cur.executescript('''
DROP TABLE IF EXISTS User;
DROP TABLE IF EXISTS Member;
DROP TABLE IF EXISTS Course;

CREATE TABLE User (
    id     INTEGER NOT NULL PRIMARY KEY AUTOINCREMENT UNIQUE,
    name   TEXT UNIQUE
);

CREATE TABLE Course (
    id     INTEGER NOT NULL PRIMARY KEY AUTOINCREMENT UNIQUE,
    title  TEXT UNIQUE
);

CREATE TABLE Member (
    user_id     INTEGER,
    course_id   INTEGER,
    role        INTEGER,
    PRIMARY KEY (user_id, course_id)
)
''')

fname = input('Enter file name: ')
if len(fname) < 1:
    fname = 'roster_data.json'

# [
#   [ "Charley", "si110", 1 ],
#   [ "Mea", "si110", 0 ],

str_data = open(fname).read()
json_data = json.loads(str_data)
# print(json_data)
for entry in json_data:

    name = entry[0]
    title = entry[1]
    role = entry[2]

   # print((name, title, member))

    cur.execute('''INSERT OR IGNORE INTO User (name)
        VALUES ( ? )''', ( name, ) )
    cur.execute('SELECT id FROM User WHERE name = ? ', (name, ))
    user_id = cur.fetchone()[0]
    
    cur.execute('''INSERT OR IGNORE INTO Course (title)
        VALUES ( ? )''', ( title, ) )
    cur.execute('SELECT id FROM Course WHERE title = ? ', (title, ))
    course_id = cur.fetchone()[0]

    cur.execute('''INSERT OR REPLACE INTO Member 
        (user_id, course_id, role) VALUES ( ?, ? ,?)''',
        ( user_id, course_id, role) )

    conn.commit()
# Out:
# Enter file name:

# %%
# Out:
# Enter file name:
# [['Neeve', 'si110', 1], ['Mariena', 'si110', 0], ['Bhaaldeen', 'si110', 0], ['Creag', 'si110', 0], ['Tyllor', 'si110', 0], ['Mikee', 'si110', 0], ['Filippo', 'si110', 0], ['Kandi', 'si110', 0], ['Zeenat', 'si110', 0], ['Angela', 'si110', 0], ['Nawfal', 'si110', 0], ['Reily', 'si110', 0], ['Nasser', 'si110', 0], ['Dhani', 'si110', 0], ['Thalia', 'si110', 0], ['Shannon', 'si110', 0], ['Kaska', 'si110', 0], ['Taya', 'si110', 0], ['Toni', 'si110', 0], ['Hira', 'si110', 0], ['Nairne', 'si110', 0], ['Sabila', 'si110', 0], ['Lexi', 'si110', 0], ['Keeman', 'si106', 1], ['Presley', 'si106', 0], ['Cesar', 'si106', 0], ['Ajooni', 'si106', 0], ['Lara', 'si106', 0], ['Darragh', 'si106', 0], ['Carolanne', 'si106', 0], ['Teighen', 'si106', 0], ['Temperance', 'si106', 0], ['Brooklyn', 'si106', 0], ['Ala', 'si106', 0], ['Cassy', 'si106', 0], ['Savanah', 'si106', 0], ['Orson', 'si106', 0], ['Ashlee', 'si106', 0], ['Carris', 'si106', 0], ['Evan', 'si106', 0], ['Marcquis', 'si106', 0], ['Wayde', 'si106', 0], ['Kaidan', 'si106', 0], ['Juliette', 'si106', 0], ['Ziya', 'si106', 0], ['Camron', 'si106', 0], ['Lomond', 'si106', 0], ['Rishi', 'si106', 0], ['Kyan', 'si106', 0], ['Cobain', 'si206', 1], ['Leyia', 'si206', 0], ['Katarzyna', 'si206', 0], ['Thorfinn', 'si206', 0], ['Marwah', 'si206', 0], ['Tammara', 'si206', 0], ['Kim', 'si206', 0], ['Karhys', 'si206', 0], ['Mysha', 'si206', 0], ['Stefanie', 'si206', 0], ['Amro', 'si206', 0], ['Domenico', 'si206', 0], ['Machlan', 'si206', 0], ['Jak', 'si206', 0], ['Mario', 'si206', 0], ['Logyne', 'si206', 0], ['Atal', 'si206', 0], ['Siddhant', 'si206', 0], ['Linton', 'si206', 0], ['Christina', 'si206', 0], ['Lincon', 'si206', 0], ['Annabelle', 'si206', 0], ['Marcella', 'si206', 0], ['Caleb', 'si206', 0], ['Baillie', 'si206', 0], ['Emer', 'si206', 0], ['Zuzia', 'si301', 1], ['Monica', 'si301', 0], ['Ophelia', 'si301', 0], ['Kofi', 'si301', 0], ['Ifunanya', 'si301', 0], ['Eljon', 'si301', 0], ['Aleeza', 'si301', 0], ['Koddi', 'si301', 0], ['Konnor', 'si301', 0], ['Clodagh', 'si301', 0], ['Ewen', 'si301', 0], ['Surya', 'si301', 0], ['Hubert', 'si301', 0], ['Odhran', 'si301', 0], ['Mohammad', 'si301', 0], ['Aayat', 'si301', 0], ['Emelye', 'si301', 0], ['Sukveer', 'si301', 0], ['Eila', 'si301', 0], ['Nikiya', 'si301', 0], ['Nancy', 'si301', 0], ['Mohd', 'si301', 0], ['Rosslyn', 'si301', 0], ['Celine', 'si301', 0], ['Imman', 'si301', 0], ['Rana', 'si301', 0], ['Morgan', 'si301', 0], ['Murren', 'si301', 0], ['Matia', 'si301', 0], ['Jessica', 'si301', 0], ['Virginia', 'si301', 0], ['Caileen', 'si301', 0], ['Kailas', 'si301', 0], ['Emmanuel', 'si310', 1], ['Elize', 'si310', 0], ['Derick', 'si310', 0], ['Bente', 'si310', 0], ['Elsi', 'si310', 0], ['Youssef', 'si310', 0], ['Alaa', 'si310', 0], ['Kaileigh', 'si310', 0], ['Suze', 'si310', 0], ['Reilly', 'si310', 0], ['Lyla', 'si310', 0], ['Pasquale', 'si310', 0], ['Kizhi', 'si310', 0], ['Kisha', 'si310', 0], ['Kacee', 'si310', 0], ['Armaan', 'si310', 0], ['Anwen', 'si310', 0], ['Ruqayah', 'si310', 0], ['Kenzi', 'si310', 0], ['Bodhan', 'si310', 0], ['Nathan', 'si310', 0], ['Morvyn', 'si310', 0], ['Brandon', 'si310', 0], ['Andrejs', 'si310', 0], ['Raithin', 'si310', 0], ['Miao', 'si310', 0], ['Rafi', 'si310', 0], ['Lennon', 'si310', 0], ['Shyam', 'si310', 0], ['Ellis', 'si310', 0], ['Ainsley', 'si310', 0], ['Nawel', 'si310', 0], ['Blanka', 'si310', 0], ['Ausra', 'si310', 0], ['Bailee', 'si310', 0], ['Kia', 'si310', 0], ['Rzan', 'si310', 0], ['Ice', 'si310', 0], ['Jenni', 'si310', 0], ['Stephany', 'si310', 0], ['Sherese', 'si310', 0], ['Kriss', 'si310', 0], ['Wojciech', 'si310', 0], ['Elspeth', 'si310', 0], ['Kendal', 'si310', 0], ['Haneeah', 'si310', 0], ['Renas', 'si310', 0], ['Vince', 'si310', 0], ['Nikita', 'si334', 1], ['Odhran', 'si334', 0], ['Allannah', 'si334', 0], ['Lauren', 'si334', 0], ['Caryss', 'si334', 0], ['Billy', 'si334', 0], ['Eubh', 'si334', 0], ['Yusef', 'si334', 0], ['Janet', 'si334', 0], ['Ksawery', 'si334', 0], ['Mishkat', 'si334', 0], ['Orlah', 'si334 ...
# ('Neeve', 'si110')
# ('Mariena', 'si110')
# ('Bhaaldeen', 'si110')
# ('Creag', 'si110')
# ('Tyllor', 'si110')
# ('Mikee', 'si110')
# ('Filippo', 'si110')
# ('Kandi', 'si110')
# ('Zeenat', 'si110')
# ('Angela', 'si110')
# ('Nawfal', 'si110')
# ('Reily', 'si110')
# ('Nasser', 'si110')
# ('Dhani', 'si110')
# ('Thalia', 'si110')
# ('Shannon', 'si110')
# ('Kaska', 'si110')
# ('Taya', 'si110')
# ('Toni', 'si110')
# ('Hira', 'si110')
# ('Nairne', 'si110')
# ('Sabila', 'si110')
# ('Lexi', 'si110')
# ('Keeman', 'si106')
# ('Presley', 'si106')
# ('Cesar', 'si106')
# ('Ajooni', 'si106')
# ('Lara', 'si106')
# ('Darragh', 'si106')
# ('Carolanne', 'si106')
# ('Teighen', 'si106')
# ('Temperance', 'si106')
# ('Brooklyn', 'si106')
# ('Ala', 'si106')
# ('Cassy', 'si106')
# ('Savanah', 'si106')
# ('Orson', 'si106')
# ('Ashlee', 'si106')
# ('Carris', 'si106')
# ('Evan', 'si106')
# ('Marcquis', 'si106')
# ('Wayde', 'si106')
# ('Kaidan', 'si106')
# ('Juliette', 'si106')
# ('Ziya', 'si106')
# ('Camron', 'si106')
# ('Lomond', 'si106')
# ('Rishi', 'si106')
# ('Kyan', 'si106')
# ('Cobain', 'si206')
# ('Leyia', 'si206')
# ('Katarzyna', 'si206')
# ('Thorfinn', 'si206')
# ('Marwah', 'si206')
# ('Tammara', 'si206')
# ('Kim', 'si206')
# ('Karhys', 'si206')
# ('Mysha', 'si206')
# ('Stefanie', 'si206')
# ('Amro', 'si206')
# ('Domenico', 'si206')
# ('Machlan', 'si206')
# ('Jak', 'si206')
# ('Mario', 'si206')
# ('Logyne', 'si206')
# ('Atal', 'si206')
# ('Siddhant', 'si206')
# ('Linton', 'si206')
# ('Christina', 'si206')
# ('Lincon', 'si206')
# ('Annabelle', 'si206')
# ('Marcella', 'si206')
# ('Caleb', 'si206')
# ('Baillie', 'si206')
# ('Emer', 'si206')
# ('Zuzia', 'si301')
# ('Monica', 'si301')
# ('Ophelia', 'si301')
# ('Kofi', 'si301')
# ('Ifunanya', 'si301')
# ('Eljon', 'si301')
# ('Aleeza', 'si301')
# ('Koddi', 'si301')
# ('Konnor', 'si301')
# ('Clodagh', 'si301')
# ('Ewen', 'si301')
# ('Surya', 'si301')
# ('Hubert', 'si301')
# ('Odhran', 'si301')
# ('Mohammad', 'si301')
# ('Aayat', 'si301')
# ('Emelye', 'si301')
# ('Sukveer', 'si301')
# ('Eila', 'si301')
# ('Nikiya', 'si301')
# ('Nancy', 'si301')
# ('Mohd', 'si301')
# ('Rosslyn', 'si301')
# ('Celine', 'si301')
# ('Imman', 'si301')
# ('Rana', 'si301')
# ('Morgan', 'si301')
# ('Murren', 'si301')
# ('Matia', 'si301')
# ('Jessica', 'si301')
# ('Virginia', 'si301')
# ('Caileen', 'si301')
# ('Kailas', 'si301')
# ('Emmanuel', 'si310')
# ('Elize', 'si310')
# ('Derick', 'si310')
# ('Bente', 'si310')
# ('Elsi', 'si310')
# ('Youssef', 'si310')
# ('Alaa', 'si310')
# ('Kaileigh', 'si310')
# ('Suze', 'si310')
# ('Reilly', 'si310')
# ('Lyla', 'si310')
# ('Pasquale', 'si310')
# ('Kizhi', 'si310')
# ('Kisha', 'si310')
# ('Kacee', 'si310')
# ('Armaan', 'si310')
# ('Anwen', 'si310')
# ('Ruqayah', 'si310')
# ('Kenzi', 'si310')
# ('Bodhan', 'si310')
# ('Nathan', 'si310')
# ('Morvyn', 'si310')
# ('Brandon', 'si310')
# ('Andrejs', 'si310')
# ('Raithin', 'si310')
# ('Miao', 'si310')
# ('Rafi', 'si310')
# ('Lennon', 'si310')
# ('Shyam', 'si310')
# ('Ellis', 'si310')
# ('Ainsley', 'si310')
# ('Nawel', 'si310')
# ('Blanka', 'si310')
# ('Ausra', 'si310')
# ('Bailee', 'si310')
# ('Kia', 'si310')
# ('Rzan', 'si310')
# ('Ice', 'si310')
# ('Jenni', 'si310')
# ('Stephany', 'si310')
# ('Sherese', 'si310')
# ('Kriss', 'si310')
# ('Wojciech', 'si310')
# ('Elspeth', 'si310')
# ('Kendal', 'si310')
# ('Haneeah', 'si310')
# ('Renas', 'si310')
# ('Vince', 'si310')
# ('Nikita', 'si334')
# ('Odhran', 'si334')
# ('Allannah', 'si334')
# ('Lauren', 'si334')
# ('Caryss', 'si334')
# ('Billy', 'si334')
# ('Eubh', 'si334')
# ('Yusef', 'si334')
# ('Janet', 'si334')
# ('Ksawery', 'si334')
# ('Mishkat', 'si334')
# ('Orlah', 'si334')
# ('Liyah', 'si334')
# ('Damla', 'si334')
# ('Rhianne', 'si334')
# ('Valerie', 'si334')
# ('Avesta', 'si334')
# ('Kalia', 'si334')
# ('Mackie', 'si334')
# ('Chester', 'si334')
# ('Terry', 'si334')
# ('Bartosz', 'si334')
# ('Santino', 'si334')
# ('Aamna', 'si363')
# ('Ashwin', 'si363')
# ('Riven', 'si363')
# ('Corran', 'si363')
# ('Kate', 'si363')
# ('Tyla', 'si363')
# ('Oluwaferanmi', 'si363')
# ('Bradly', 'si363')
# ('Mowmita', 'si363')
# ('Analucia', 'si363')
# ('Kieya', 'si363')
# ('Ailin', 'si363')
# ('Layton', 'si363')
# ('Saliha', 'si363')
# ('Elivia', 'si363')
# ('Aurora', 'si363')
# ('Gavin', 'si363')
# ('Digby', 'si363')
# ('Neiv', 'si363')
# ('Dougal', 'si363')
# ('Balian', 'si363')
# ('Bryden', 'si363')
# ('Izabella', 'si363')
# ('Cobie', 'si363')
# ('Teagan', 'si363')
# ('Zubair', 'si363')
# ('Corrin', 'si363')
# ('Kalvyn', 'si363')
# ('Kallen', 'si363')
# ('Katrin', 'si363')
# ('Cruiz', 'si364')
# ('Rosslyn', 'si364')
# ('Ameerah', 'si364')
# ('Henri', 'si364')
# ('Atiya', 'si364')
# ('Kendra', 'si364')
# ('Belle', 'si364')
# ('Carrich', 'si364')
# ('Fion', 'si364')
# ('Harold', 'si364')
# ('Amez', 'si364')
# ('Harri', 'si364')
# ('Todd', 'si364')
# ('Izaak', 'si364')
# ('Cody', 'si364')
# ('Maci', 'si364')
# ('Dolan', 'si364')
# ('Hassan', 'si364')
# ('Lorin', 'si364')
# ('Scarlett', 'si364')
# ('Darcy', 'si364')
# ('Demilee', 'si364')
# ('Pieter', 'si364')
# ('Patsy', 'si364')
# ('Israa', 'si364')
# ('Jaii', 'si364')
# ('Johanna', 'si364')
# ('Calley', 'si364')
# ('Brenae', 'si364')
# ('Sofian', 'si364')
# ('Cambell', 'si364')
# ('Muneeba', 'si364')
# ('Hafiza', 'si364')
# ('Maram', 'si364')
# ('Pola', 'si364')
# ('Nawal', 'si364')
# ('Fynlay', 'si364')
# ('Data', 'si364')
# ('Samir', 'si364')
# ('Sarahlouise', 'si364')
# ('Rishi', 'si364')
# ('Cian', 'si364')
# ('Akram', 'si364')
# ('Kiyara', 'si364')
# ('Vicky', 'si364')
# ('Babyjane', 'si364')
# ('Jordin', 'si364')
# ('Teah', 'si422')
# ('Billie', 'si422')
# ('Leanne', 'si422')
# ('Reynold', 'si422')
# ('Cassandra', 'si422')
# ('Leechan', 'si422')
# ('Lyle', 'si422')
# ('Tymom', 'si422')
# ('Pierce', 'si422')
# ('Anisa', 'si422')
# ('Lilly', 'si422')
# ('Kenton', 'si422')
# ('Aliya', 'si422')
# ('Sayad', 'si422')
# ('Tianna', 'si422')
# ('Lila', 'si422')
# ('Bryson', 'si422')
# ('Nur', 'si422')
# ('Iain', 'si422')
# ('Anayah', 'si422')
# ('Kavita', 'si422')
# ('Carrich', 'si422')
# ('Ngonidzashe', 'si422')
# ('Travis', 'si422')
# ('Blaike', 'si422')
# ('Tane', 'si422')
# ('Karson', 'si422')
# ('Seonaidh', 'si422')
# ('Ellice', 'si422')
# ('Gjan', 'si422')
# ('Siergiej', 'si422')
# ('Alise', 'si422')
# ('Nihal', 'si422')
# ('Ameera', 'si422')
# ('Ally', 'si422')
# ('Bushra', 'si422')
# ('Danish', 'si422')
# ('Taylar', 'si422')
# ('Joaquin', 'si422')
# ('Haidyn', 'si422')
# ('Melissande', 'si422')
# ('Rosslyn', 'si422')
# ('Ezri', 'si422')
# ('Eesa', 'si422')
# ('Madelyn', 'si430')
# ('Julian', 'si430')
# ('Nur', 'si430')
# ('Valeria', 'si430')
# ('Graham', 'si430')
# ('Ridwan', 'si430')
# ('Leonah', 'si430')
# ('Nicholas', 'si430')
# ('Codey', 'si430')
# ('Allesandro', 'si430')
# ('Delilah', 'si430')
# ('Rowan', 'si430')
# ('Ivar', 'si430')
# ('Andi', 'si430')
# ('Fatimah', 'si430')
# ('Aadam', 'si430')
# ('Malaeka', 'si430')
# ('Hafsah', 'si430')
# ('Nola', 'si430')
# ('Jaii', 'si430')
# ('Divine', 'si430')
# ('Kristoffer', 'si430')
# ('Bryan', 'si430')
# ('Kareena', 'si430')
# ('Katherine', 'si430')
# ('Arshjoyat', 'si430')
# ('Macy', 'si430')
# ('Lockey', 'si430')
# ('Youcef', 'si430')
# ('Rubhan', 'si430')
