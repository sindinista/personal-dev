# %% [markdown]
# ---
#
# _You are currently looking at **version 1.1** of this notebook. To download notebooks and datafiles, as well as get help on Jupyter notebooks in the Coursera platform, visit the [Jupyter Notebook FAQ](https://www.coursera.org/learn/python-data-analysis/resources/0dhYG) course resource._
#
# ---

# %%
import pandas as pd
import numpy as np
import re
from scipy.stats import ttest_ind

# %% [markdown]
# # Assignment 4 - Hypothesis Testing
# This assignment requires more individual learning than previous assignments - you are encouraged to check out the [pandas documentation](http://pandas.pydata.org/pandas-docs/stable/) to find functions or methods you might not have used yet, or ask questions on [Stack Overflow](http://stackoverflow.com/) and tag them as pandas and python related. And of course, the discussion forums are open for interaction with your peers and the course staff.
#
# Definitions:
# * A _quarter_ is a specific three month period, Q1 is January through March, Q2 is April through June, Q3 is July through September, Q4 is October through December.
# * A _recession_ is defined as starting with two consecutive quarters of GDP decline, and ending with two consecutive quarters of GDP growth.
# * A _recession bottom_ is the quarter within a recession which had the lowest GDP.
# * A _university town_ is a city which has a high percentage of university students compared to the total population of the city.
#
# **Hypothesis**: University towns have their mean housing prices less effected by recessions. Run a t-test to compare the ratio of the mean price of houses in university towns the quarter before the recession starts compared to the recession bottom. (`price_ratio=quarter_before_recession/recession_bottom`)
#
# The following data files are available for this assignment:
# * From the [Zillow research data site](http://www.zillow.com/research/data/) there is housing data for the United States. In particular the datafile for [all homes at a city level](http://files.zillowstatic.com/research/public/City/City_Zhvi_AllHomes.csv), ```City_Zhvi_AllHomes.csv```, has median home sale prices at a fine grained level.
# * From the Wikipedia page on college towns is a list of [university towns in the United States](https://en.wikipedia.org/wiki/List_of_college_towns#College_towns_in_the_United_States) which has been copy and pasted into the file ```university_towns.txt```.
# * From Bureau of Economic Analysis, US Department of Commerce, the [GDP over time](http://www.bea.gov/national/index.htm#gdp) of the United States in current dollars (use the chained value in 2009 dollars), in quarterly intervals, in the file ```gdplev.xls```. For this assignment, only look at GDP data from the first quarter of 2000 onward.
#
# Each function in this assignment below is worth 10%, with the exception of ```run_ttest()```, which is worth 50%.

# %%
# Use this dictionary to map state names to two letter acronyms
states = {'OH': 'Ohio', 'KY': 'Kentucky', 'AS': 'American Samoa', 'NV': 'Nevada', 'WY': 'Wyoming', 'NA': 'National', 'AL': 'Alabama', 'MD': 'Maryland', 'AK': 'Alaska', 'UT': 'Utah', 'OR': 'Oregon', 'MT': 'Montana', 'IL': 'Illinois', 'TN': 'Tennessee', 'DC': 'District of Columbia', 'VT': 'Vermont', 'ID': 'Idaho', 'AR': 'Arkansas', 'ME': 'Maine', 'WA': 'Washington', 'HI': 'Hawaii', 'WI': 'Wisconsin', 'MI': 'Michigan', 'IN': 'Indiana', 'NJ': 'New Jersey', 'AZ': 'Arizona', 'GU': 'Guam', 'MS': 'Mississippi', 'PR': 'Puerto Rico', 'NC': 'North Carolina', 'TX': 'Texas', 'SD': 'South Dakota', 'MP': 'Northern Mariana Islands', 'IA': 'Iowa', 'MO': 'Missouri', 'CT': 'Connecticut', 'WV': 'West Virginia', 'SC': 'South Carolina', 'LA': 'Louisiana', 'KS': 'Kansas', 'NY': 'New York', 'NE': 'Nebraska', 'OK': 'Oklahoma', 'FL': 'Florida', 'CA': 'California', 'CO': 'Colorado', 'PA': 'Pennsylvania', 'DE': 'Delaware', 'NM': 'New Mexico', 'RI': 'Rhode Island', 'MN': 'Minnesota', 'VI': 'Virgin Islands', 'NH': 'New Hampshire', 'MA': 'Massachusetts', 'GA': 'Georgia', 'ND': 'North Dakota', 'VA': 'Virginia'}

# %%
def get_list_of_university_towns():
    '''Returns a DataFrame of towns and the states they are in from the 
    university_towns.txt list. The format of the DataFrame should be:
    DataFrame( [ ["Michigan", "Ann Arbor"], ["Michigan", "Yipsilanti"] ], 
    columns=["State", "RegionName"]  )
    
    The following cleaning needs to be done:

    1. For "State", removing characters from "[" to the end.
    2. For "RegionName", when applicable, removing every character from " (" to the end.
    3. Depending on how you read the data, you may need to remove newline character '\n'. '''

# %%
uni = (pd.read_csv('university_towns.txt',
                  names=['UniTown']))

# %%
state = []
for i in uni.itertuples() :
    if "[edit]" in i[1] :
        state.append(i[1].split('[')[0])
        uni.at[i.index, 'State'] == state[-1]
    else :
        print('unitown', i[1].split(' (')[0], state[-1])
# Out:
# state ['Alabama']
# unitown Auburn Alabama
# unitown Florence Alabama
# unitown Jacksonville Alabama
# unitown Livingston Alabama
# unitown Montevallo Alabama
# unitown Troy Alabama
# unitown Tuscaloosa Alabama
# unitown Tuskegee Alabama
# state ['Alabama', 'Alaska']
# unitown Fairbanks Alaska
# state ['Alabama', 'Alaska', 'Arizona']
# unitown Flagstaff Arizona
# unitown Tempe Arizona
# unitown Tucson Arizona
# state ['Alabama', 'Alaska', 'Arizona', 'Arkansas']
# unitown Arkadelphia Arkansas
# unitown Conway Arkansas
# unitown Fayetteville Arkansas
# unitown Jonesboro Arkansas
# unitown Magnolia Arkansas
# unitown Monticello Arkansas
# unitown Russellville Arkansas
# unitown Searcy Arkansas
# state ['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California']
# unitown Angwin California
# unitown Arcata California
# unitown Berkeley California
# unitown Chico California
# unitown Claremont California
# unitown Cotati California
# unitown Davis California
# unitown Irvine California
# unitown Isla Vista California
# unitown University Park California
# unitown Merced California
# unitown Orange California
# unitown Palo Alto California
# unitown Pomona California
# unitown Redlands California
# unitown Riverside California
# unitown Sacramento California
# unitown University District California
# unitown San Diego California
# unitown San Luis Obispo California
# unitown Santa Barbara California
# unitown Santa Cruz California
# unitown Turlock California
# unitown Westwood California
# unitown Whittier California
# state ['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California', 'Colorado']
# unitown Alamosa Colorado
# unitown Boulder Colorado
# unitown Durango Colorado
# unitown Fort Collins Colorado
# unitown Golden Colorado
# unitown Grand Junction Colorado
# unitown Greeley Colorado
# unitown Gunnison Colorado
# unitown Pueblo Colorado
# state ['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California', 'Colorado', 'Connecticut']
# unitown Fairfield Connecticut
# unitown Middletown Connecticut
# unitown New Britain Connecticut
# unitown New Haven Connecticut
# unitown New London Connecticut
# unitown Storrs Connecticut
# unitown Willimantic Connecticut
# state ['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California', 'Colorado', 'Connecticut', 'Delaware']
# unitown Dover Delaware
# unitown Newark Delaware
# state ['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California', 'Colorado', 'Connecticut', 'Delaware', 'Florida']
# unitown Ave Maria Florida
# unitown Boca Raton Florida
# unitown Coral Gables Florida
# unitown DeLand Florida
# unitown Estero Florida
# unitown Gainesville Florida
# unitown Orlando Florida
# unitown Sarasota Florida
# unitown St. Augustine Florida
# unitown St. Leo Florida
# unitown Tallahassee Florida
# unitown Tampa Florida
# state ['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California', 'Colorado', 'Connecticut', 'Delaware', 'Florida', 'Georgia']
# unitown Albany Georgia
# unitown Athens Georgia
# unitown Atlanta Georgia
# unitown Carrollton Georgia
# unitown Demorest Georgia
# unitown Fort Valley Georgia
# unitown Kennesaw Georgia
# unitown Milledgeville Georgia
# unitown Mount Vernon Georgia
# unitown Oxford Georgia
# unitown Rome Georgia
# unitown Savannah Georgia
# unitown Statesboro Georgia
# unitown Valdosta Georgia
# unitown Waleska Georgia
# unitown Young Harris Georgia
# state ['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California', 'Colorado', 'Connecticut', 'Delaware', 'Florida', 'Georgia', 'Hawaii']
# unitown Manoa Hawaii
# state ['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California', 'Colorado', 'Connecticut', 'Delaware', 'Florida', 'Georgia', 'Hawaii', 'Idaho']
# unitown Moscow Idaho
# unitown Pocatello Idaho
# unitown Rexburg Idaho
# state ['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California', 'Colorado', 'Connecticut', 'Delaware', 'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois']
# unitown Carbondale Illinois
# unitown Champaign–Urbana Illinois
# unitown Charleston Illinois
# unitown DeKalb Illinois
# unitown Edwardsville Illinois
# unitown Evanston Illinois
# unitown Lebanon Illinois
# unitown Macomb Illinois
# unitown Normal Illinois
# unitown Peoria Illinois
# state ['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California', 'Colorado', 'Connecticut', 'Delaware', 'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana']
# unitown Bloomington Indiana
# unitown Crawfordsville Indiana
# unitown Greencastle Indiana
# unitown Hanover Indiana
# unitown Marion Indiana
# unitown Muncie Indiana
# unitown Oakland City Indiana
# unitown Richmond Indiana
# unitown South Bend Indiana
# unitown Terre Haute Indiana
# unitown Upland Indiana
# unitown Valparaiso Indiana
# unitown West Lafayette Indiana
# state ['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California', 'Colorado', 'Connecticut', 'Delaware', 'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana', 'Iowa']
# unitown Ames Iowa
# unitown Cedar Falls Iowa
# unitown Cedar Rapids Iowa
# unitown Decorah Iowa
# unitown Fayette Iowa
# unitown Grinnell Iowa
# unitown Iowa City Iowa
# unitown Lamoni Iowa
# unitown Mount Vernon Iowa
# unitown Orange City Iowa
# unitown Sioux Center Iowa
# unitown Storm Lake Iowa
# unitown Waverly Iowa
# state ['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California', 'Colorado', 'Connecticut', 'Delaware', 'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana', 'Iowa', 'Kansas']
# unitown Baldwin City Kansas
# unitown Emporia Kansas
# unitown Hays Kansas
# unitown Lawrence Kansas
# unitown Manhattan Kansas
# unitown Pittsburg Kansas
# state ['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California', 'Colorado', 'Connecticut', 'Delaware', 'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana', 'Iowa', 'Kansas', 'Kentucky']
# unitown Bowling Green Kentucky
# unitown Columbia Kentucky
# unitown Georgetown Kentucky
# unitown Highland Heights Kentucky
# unitown Lexington Kentucky
# unitown Louisville Kentucky
# unitown Morehead Kentucky
# unitown Murray Kentucky
# unitown Richmond Kentucky
# unitown Williamsburg Kentucky
# unitown Wilmore Kentucky
# state ['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California', 'Colorado', 'Connecticut', 'Delaware', 'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana', 'Iowa', 'Kansas', 'Kentucky', 'Louisiana']
# unitown Baton Rouge Louisiana
# unitown Grambling Louisiana
# unitown Hammond Louisiana
# unitown Lafayette Louisiana
# unitown Monroe Louisiana
# unitown Natchitoches Louisiana
# unitown Ruston Louisiana
# unitown Thibodaux Louisiana
# state ['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California', 'Colorado', 'Connecticut', 'Delaware', 'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana', 'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine']
# unitown Augusta Maine
# unitown Bar Harbor Maine
# unitown Brunswick Maine
# unitown Farmington Maine
# unitown Fort Kent Maine
# unitown Gorham Maine
# unitown Lewiston Maine
# unitown Orono Maine
# unitown Waterville Maine
# state ['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California', 'Colorado', 'Connecticut', 'Delaware', 'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana', 'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland']
# unitown Annapolis Maryland
# unitown Chestertown Maryland
# unitown College Park Maryland
# unitown Cumberland Maryland
# unitown Emmitsburg Maryland
# unitown Frostburg Maryland
# unitown Princess Anne Maryland
# unitown Towson Maryland
# unitown Salisbury Maryland
# unitown Westminster Maryland
# state ['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California', 'Colorado', 'Connecticut', 'Delaware', 'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana', 'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland', 'Massachusetts']
# unitown Boston Massachusetts
# unitown Bridgewater Massachusetts
# unitown Cambridge Massachusetts
# unitown Chestnut Hill Massachusetts
# unitown The Colleges of Worcester Consortium: Massachusetts
# unitown Dudley Massachusetts
# unitown North Grafton Massachusetts
# unitown Paxton Massachusetts
# unitown Worcester Massachusetts
# unitown The Five College Region of Western Massachusetts: Massachusetts
# unitown Amherst Massachusetts
# unitown Northampton Massachusetts
# unitown South Hadley Massachusetts
# unitown Fitchburg Massachusetts
# unitown North Adams Massachusetts
# unitown Springfield Massachusetts
# unitown Waltham Massachusetts
# unitown Williamstown Massachusetts
# unitown Framingham Massachusetts
# state ['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California', 'Colorado', 'Connecticut', 'Delaware', 'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana', 'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland', 'Massachusetts', 'Michigan']
# unitown Adrian Michigan
# unitown Albion Michigan
# unitown Allendale Michigan
# unitown Alma Michigan
# unitown Ann Arbor Michigan
# unitown Berrien Springs Michigan
# unitown Big Rapids Michigan
# unitown East Lansing Michigan
# unitown Flint Michigan
# unitown Hillsdale Michigan
# unitown Houghton Michigan
# unitown Kalamazoo Michigan
# unitown Marquette Michigan
# unitown Midland Michigan
# unitown Mount Pleasant Michigan
# unitown Olivet Michigan
# unitown Saginaw Michigan
# unitown Sault Ste. Marie Michigan
# unitown Spring Arbor Michigan
# unitown Ypsilanti Michigan
# state ['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California', 'Colorado', 'Connecticut', 'Delaware', 'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana', 'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland', 'Massachusetts', 'Michigan', 'Minnesota']
# unitown Bemidji Minnesota
# unitown Crookston Minnesota
# unitown Duluth Minnesota
# unitown Faribault Minnesota
# unitown Mankato Minnesota
# unitown Marshall Minnesota
# unitown Moorhead Minnesota
# unitown Morris Minnesota
# unitown Northfield Minnesota
# unitown North Mankato Minnesota
# unitown St. Cloud Minnesota
# unitown St. Joseph Minnesota
# unitown St. Peter Minnesota
# unitown Winona Minnesota
# state ['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California', 'Colorado', 'Connecticut', 'Delaware', 'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana', 'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland', 'Massachusetts', 'Michigan', 'Minnesota', 'Mississippi']
# unitown Cleveland Mississippi
# unitown Hattiesburg Mississippi
# unitown Itta Bena Mississippi
# unitown Oxford Mississippi
# unitown Starkville Mississippi
# state ['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California', 'Colorado', 'Connecticut', 'Delaware', 'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana', 'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland', 'Massachusetts', 'Michigan', 'Minnesota', 'Mississippi', 'Missouri']
# unitown Bolivar Missouri
# unitown Cape Girardeau Missouri
# unitown Columbia Missouri
# unitown Fayette Missouri
# unitown Fulton Missouri
# unitown Kirksville Missouri
# unitown Maryville Missouri
# unitown Rolla Missouri
# unitown Warrensburg Missouri
# state ['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California', 'Colorado', 'Connecticut', 'Delaware', 'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana', 'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland', 'Massachusetts', 'Michigan', 'Minnesota', 'Mississippi', 'Missouri', 'Montana']
# unitown Bozeman Montana
# unitown Dillon Montana
# unitown Missoula Montana
# state ['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California', 'Colorado', 'Connecticut', 'Delaware', 'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana', 'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland', 'Massachusetts', 'Michigan', 'Minnesota', 'Mississippi', 'Missouri', 'Montana', 'Nebraska']
# unitown Chadron Nebraska
# unitown Crete Nebraska
# unitown Kearney Nebraska
# unitown Lincoln Nebraska
# unitown Peru Nebraska
# unitown Seward Nebraska
# unitown Wayne Nebraska
# state ['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California', 'Colorado', 'Connecticut', 'Delaware', 'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana', 'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland', 'Massachusetts', 'Michigan', 'Minnesota', 'Mississippi', 'Missouri', 'Montana', 'Nebraska', 'Nevada']
# unitown Las Vegas Nevada
# unitown Reno Nevada
# state ['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California', 'Colorado', 'Connecticut', 'Delaware', 'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana', 'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland', 'Massachusetts', 'Michigan', 'Minnesota', 'Mississippi', 'Missouri', 'Montana', 'Nebraska', 'Nevada', 'New Hampshire']
# unitown New London New Hampshire
# unitown Durham New Hampshire
# unitown Hanover New Hampshire
# unitown Henniker New Hampshire
# unitown Keene New Hampshire
# unitown Plymouth New Hampshire
# unitown Rindge New Hampshire
# state ['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California', 'Colorado', 'Connecticut', 'Delaware', 'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana', 'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland', 'Massachusetts', 'Michigan', 'Minnesota', 'Mississippi', 'Missouri', 'Montana', 'Nebraska', 'Nevada', 'New Hampshire', 'New Jersey']
# unitown Ewing New Jersey
# unitown Jersey City New Jersey
# unitown Glassboro New Jersey
# unitown Hoboken New Jersey
# unitown Madison New Jersey
# unitown Newark New Jersey
# unitown New Brunswick New Jersey
# unitown Princeton New Jersey
# unitown Union New Jersey
# unitown West Long Branch New Jersey
# state ['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California', 'Colorado', 'Connecticut', 'Delaware', 'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana', 'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland', 'Massachusetts', 'Michigan', 'Minnesota', 'Mississippi', 'Missouri', 'Montana', 'Nebraska', 'Nevada', 'New Hampshire', 'New Jersey', 'New Mexico']
# unitown Hobbs New Mexico
# unitown Las Cruces New Mexico
# unitown Las Vegas New Mexico
# unitown Portales New Mexico
# unitown Silver City New Mexico
# state ['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California', 'Colorado', 'Connecticut', 'Delaware', 'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana', 'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland', 'Massachusetts', 'Michigan', 'Minnesota', 'Mississippi', 'Missouri', 'Montana', 'Nebraska', 'Nevada', 'New Hampshire', 'New Jersey', 'New Mexico', 'New York']
# unitown Alfred New York
# unitown Albany New York
# unitown Aurora New York
# unitown Binghamton New York
# unitown Brockport New York
# unitown Buffalo New York
# unitown Canton New York
# unitown Clinton New York
# unitown Cobleskill New York
# unitown Delhi New York
# unitown Fredonia New York
# unitown Geneseo New York
# unitown Geneva New York
# unitown Hamilton New York
# unitown Ithaca New York
# unitown Morningside Heights New York
# unitown New Paltz New York
# unitown Oneonta New York
# unitown Oswego New York
# unitown Plattsburgh New York
# unitown Potsdam New York
# unitown Poughkeepsie New York
# unitown Purchase New York
# unitown Rochester New York
# unitown Saratoga Springs New York
# unitown Seneca Falls New York
# unitown Stony Brook New York
# unitown Syracuse New York
# unitown Tivoli New York
# unitown Troy New York
# unitown West Point New York
# state ['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California', 'Colorado', 'Connecticut', 'Delaware', 'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana', 'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland', 'Massachusetts', 'Michigan', 'Minnesota', 'Mississippi', 'Missouri', 'Montana', 'Nebraska', 'Nevada', 'New Hampshire', 'New Jersey', 'New Mexico', 'New York', 'North Carolina']
# unitown Banner Elk North Carolina
# unitown Boiling Springs North Carolina
# unitown Boone North Carolina
# unitown Buies Creek North Carolina
# unitown Chapel Hill North Carolina
# unitown Cullowhee North Carolina
# unitown Davidson North Carolina
# unitown Durham North Carolina
# unitown Elon North Carolina
# unitown Greensboro North Carolina
# unitown Greenville North Carolina
# unitown Hickory North Carolina
# unitown Mars Hill North Carolina
# unitown Mount Olive North Carolina
# unitown Pembroke North Carolina
# unitown Wilmington North Carolina
# unitown Wingate North Carolina
# unitown Winston-Salem North Carolina
# state ['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California', 'Colorado', 'Connecticut', 'Delaware', 'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana', 'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland', 'Massachusetts', 'Michigan', 'Minnesota', 'Mississippi', 'Missouri', 'Montana', 'Nebraska', 'Nevada', 'New Hampshire', 'New Jersey', 'New Mexico', 'New York', 'North Carolina', 'North Dakota']
# unitown Fargo North Dakota
# unitown Grand Forks North Dakota
# state ['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California', 'Colorado', 'Connecticut', 'Delaware', 'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana', 'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland', 'Massachusetts', 'Michigan', 'Minnesota', 'Mississippi', 'Missouri', 'Montana', 'Nebraska', 'Nevada', 'New Hampshire', 'New Jersey', 'New Mexico', 'New York', 'North Carolina', 'North Dakota', 'Ohio']
# unitown Ada Ohio
# unitown Alliance Ohio
# unitown Ashland Ohio
# unitown Athens Ohio
# unitown Berea Ohio
# unitown Bluffton Ohio
# unitown Bowling Green Ohio
# unitown Cedarville Ohio
# unitown Columbus Ohio
# unitown Delaware Ohio
# unitown Fairborn Ohio
# unitown Findlay Ohio
# unitown Gambier Ohio
# unitown Granville Ohio
# unitown Hiram Ohio
# unitown Kent Ohio
# unitown Nelsonville Ohio
# unitown New Concord Ohio
# unitown Oberlin Ohio
# unitown Oxford Ohio
# unitown Rio Grande Ohio
# unitown Wilberforce Ohio
# state ['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California', 'Colorado', 'Connecticut', 'Delaware', 'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana', 'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland', 'Massachusetts', 'Michigan', 'Minnesota', 'Mississippi', 'Missouri', 'Montana', 'Nebraska', 'Nevada', 'New Hampshire', 'New Jersey', 'New Mexico', 'New York', 'North Carolina', 'North Dakota', 'Ohio', 'Oklahoma']
# unitown Ada Oklahoma
# unitown Alva Oklahoma
# unitown Durant Oklahoma
# unitown Edmond Oklahoma
# unitown Goodwell Oklahoma
# unitown Langston Oklahoma
# unitown Norman Oklahoma
# unitown Stillwater Oklahoma
# unitown Tahlequah Oklahoma
# unitown Tulsa Oklahoma
# unitown Weatherford Oklahoma
# state ['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California', 'Colorado', 'Connecticut', 'Delaware', 'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana', 'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland', 'Massachusetts', 'Michigan', 'Minnesota', 'Mississippi', 'Missouri', 'Montana', 'Nebraska', 'Nevada', 'New Hampshire', 'New Jersey', 'New Mexico', 'New York', 'North Carolina', 'North Dakota', 'Ohio', 'Oklahoma', 'Oregon']
# unitown Ashland Oregon
# unitown Corvallis Oregon
# unitown Eugene Oregon
# unitown Forest Grove Oregon
# unitown Klamath Falls Oregon
# unitown La Grande Oregon
# unitown Marylhurst Oregon
# unitown McMinnville Oregon
# unitown Monmouth Oregon
# unitown Newberg Oregon
# state ['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California', 'Colorado', 'Connecticut', 'Delaware', 'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana', 'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland', 'Massachusetts', 'Michigan', 'Minnesota', 'Mississippi', 'Missouri', 'Montana', 'Nebraska', 'Nevada', 'New Hampshire', 'New Jersey', 'New Mexico', 'New York', 'North Carolina', 'North Dakota', 'Ohio', 'Oklahoma', 'Oregon', 'Pennsylvania']
# unitown Altoona Pennsylvania
# unitown Annville Pennsylvania
# unitown Bethlehem Pennsylvania
# unitown Bloomsburg Pennsylvania
# unitown Bradford Pennsylvania
# unitown California Pennsylvania
# unitown Carlisle Pennsylvania
# unitown Cecil B. Moore Pennsylvania
# unitown Clarion Pennsylvania
# unitown Collegeville Pennsylvania
# unitown Cresson Pennsylvania
# unitown East Stroudsburg Pennsylvania
# unitown Edinboro Pennsylvania
# unitown Erie Pennsylvania
# unitown Gettysburg Pennsylvania
# unitown Greensburg Pennsylvania
# unitown Grove City Pennsylvania
# unitown Huntingdon Pennsylvania
# unitown Indiana Pennsylvania
# unitown Johnstown Pennsylvania
# unitown Kutztown Pennsylvania
# unitown Lancaster Pennsylvania
# unitown Lewisburg Pennsylvania
# unitown Lock Haven Pennsylvania
# unitown Loretto Pennsylvania
# unitown Mansfield Pennsylvania
# unitown Meadville Pennsylvania
# unitown Mont Alto Pennsylvania
# unitown Millersville Pennsylvania
# unitown New Wilmington Pennsylvania
# unitown North East Pennsylvania
# unitown University City Pennsylvania
# unitown Oakland Pennsylvania
# unitown Reading Pennsylvania
# unitown Selinsgrove Pennsylvania
# unitown Shippensburg Pennsylvania
# unitown Slippery Rock Pennsylvania
# unitown State College Pennsylvania
# unitown Villanova Pennsylvania
# unitown Waynesburg Pennsylvania
# unitown West Chester Pennsylvania
# unitown Wilkes-Barre Pennsylvania
# unitown Williamsport Pennsylvania
# state ['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California', 'Colorado', 'Connecticut', 'Delaware', 'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana', 'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland', 'Massachusetts', 'Michigan', 'Minnesota', 'Mississippi', 'Missouri', 'Montana', 'Nebraska', 'Nevada', 'New Hampshire', 'New Jersey', 'New Mexico', 'New York', 'North Carolina', 'North Dakota', 'Ohio', 'Oklahoma', 'Oregon', 'Pennsylvania', 'Rhode Island']
# unitown Kingston Rhode Island
# unitown Providence Rhode Island
# state ['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California', 'Colorado', 'Connecticut', 'Delaware', 'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana', 'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland', 'Massachusetts', 'Michigan', 'Minnesota', 'Mississippi', 'Missouri', 'Montana', 'Nebraska', 'Nevada', 'New Hampshire', 'New Jersey', 'New Mexico', 'New York', 'North Carolina', 'North Dakota', 'Ohio', 'Oklahoma', 'Oregon', 'Pennsylvania', 'Rhode Island', 'South Carolina']
# unitown Central South Carolina
# unitown Charleston South Carolina
# unitown Clemson South Carolina
# unitown Clinton South Carolina
# unitown Columbia South Carolina
# unitown Due West South Carolina
# unitown Florence South Carolina
# unitown Greenwood South Carolina
# unitown Orangeburg South Carolina
# unitown Rock Hill South Carolina
# unitown Spartanburg South Carolina
# state ['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California', 'Colorado', 'Connecticut', 'Delaware', 'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana', 'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland', 'Massachusetts', 'Michigan', 'Minnesota', 'Mississippi', 'Missouri', 'Montana', 'Nebraska', 'Nevada', 'New Hampshire', 'New Jersey', 'New Mexico', 'New York', 'North Carolina', 'North Dakota', 'Ohio', 'Oklahoma', 'Oregon', 'Pennsylvania', 'Rhode Island', 'South Carolina', 'South Dakota']
# unitown Brookings South Dakota
# unitown Madison South Dakota
# unitown Spearfish South Dakota
# unitown Vermillion South Dakota
# state ['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California', 'Colorado', 'Connecticut', 'Delaware', 'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana', 'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland', 'Massachusetts', 'Michigan', 'Minnesota', 'Mississippi', 'Missouri', 'Montana', 'Nebraska', 'Nevada', 'New Hampshire', 'New Jersey', 'New Mexico', 'New York', 'North Carolina', 'North Dakota', 'Ohio', 'Oklahoma', 'Oregon', 'Pennsylvania', 'Rhode Island', 'South Carolina', 'South Dakota', 'Tennessee']
# unitown Chattanooga Tennessee
# unitown Collegedale Tennessee
# unitown Cookeville Tennessee
# unitown Harrogate Tennessee
# unitown Henderson Tennessee
# unitown Johnson City Tennessee
# unitown Knoxville Tennessee
# unitown Martin Tennessee
# unitown McKenzie Tennessee
# unitown Memphis Tennessee
# unitown Murfreesboro Tennessee
# unitown Nashville Tennessee
# unitown Sewanee Tennessee
# state ['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California', 'Colorado', 'Connecticut', 'Delaware', 'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana', 'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland', 'Massachusetts', 'Michigan', 'Minnesota', 'Mississippi', 'Missouri', 'Montana', 'Nebraska', 'Nevada', 'New Hampshire', 'New Jersey', 'New Mexico', 'New York', 'North Carolina', 'North Dakota', 'Ohio', 'Oklahoma', 'Oregon', 'Pennsylvania', 'Rhode Island', 'South Carolina', 'South Dakota', 'Tennessee', 'Texas']
# unitown Abilene Texas
# unitown Alpine Texas
# unitown Austin Texas
# unitown Beaumont Texas
# unitown Canyon Texas
# unitown College Station Texas
# unitown Commerce Texas
# unitown Dallas Texas
# unitown Denton Texas
# unitown Fort Worth Texas
# unitown Georgetown Texas
# unitown Huntsville Texas
# unitown Houston Texas
# unitown Keene Texas
# unitown Kingsville Texas
# unitown Lubbock Texas
# unitown Nacogdoches Texas
# unitown Plainview Texas
# unitown Prairie View Texas
# unitown San Marcos Texas
# unitown Stephenville Texas
# unitown Waco Texas
# state ['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California', 'Colorado', 'Connecticut', 'Delaware', 'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana', 'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland', 'Massachusetts', 'Michigan', 'Minnesota', 'Mississippi', 'Missouri', 'Montana', 'Nebraska', 'Nevada', 'New Hampshire', 'New Jersey', 'New Mexico', 'New York', 'North Carolina', 'North Dakota', 'Ohio', 'Oklahoma', 'Oregon', 'Pennsylvania', 'Rhode Island', 'South Carolina', 'South Dakota', 'Tennessee', 'Texas', 'Utah']
# unitown Cedar City Utah
# unitown Logan Utah
# unitown Provo Utah
# unitown Orem Utah
# unitown Salt Lake City Utah
# unitown Ephraim Utah
# state ['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California', 'Colorado', 'Connecticut', 'Delaware', 'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana', 'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland', 'Massachusetts', 'Michigan', 'Minnesota', 'Mississippi', 'Missouri', 'Montana', 'Nebraska', 'Nevada', 'New Hampshire', 'New Jersey', 'New Mexico', 'New York', 'North Carolina', 'North Dakota', 'Ohio', 'Oklahoma', 'Oregon', 'Pennsylvania', 'Rhode Island', 'South Carolina', 'South Dakota', 'Tennessee', 'Texas', 'Utah', 'Vermont']
# unitown Burlington Vermont
# unitown Castleton Vermont
# unitown Johnson Vermont
# unitown Lyndonville Vermont
# unitown Middlebury Vermont
# unitown Northfield Vermont
# state ['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California', 'Colorado', 'Connecticut', 'Delaware', 'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana', 'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland', 'Massachusetts', 'Michigan', 'Minnesota', 'Mississippi', 'Missouri', 'Montana', 'Nebraska', 'Nevada', 'New Hampshire', 'New Jersey', 'New Mexico', 'New York', 'North Carolina', 'North Dakota', 'Ohio', 'Oklahoma', 'Oregon', 'Pennsylvania', 'Rhode Island', 'South Carolina', 'South Dakota', 'Tennessee', 'Texas', 'Utah', 'Vermont', 'Virginia']
# unitown Blacksburg Virginia
# unitown Bridgewater Virginia
# unitown Charlottesville Virginia
# unitown Farmville Virginia
# unitown Fredericksburg Virginia
# unitown Harrisonburg Virginia
# unitown Lexington Virginia
# unitown Lynchburg Virginia
# unitown Radford Virginia
# unitown Williamsburg Virginia
# unitown Wise Virginia
# unitown Chesapeake Virginia
# state ['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California', 'Colorado', 'Connecticut', 'Delaware', 'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana', 'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland', 'Massachusetts', 'Michigan', 'Minnesota', 'Mississippi', 'Missouri', 'Montana', 'Nebraska', 'Nevada', 'New Hampshire', 'New Jersey', 'New Mexico', 'New York', 'North Carolina', 'North Dakota', 'Ohio', 'Oklahoma', 'Oregon', 'Pennsylvania', 'Rhode Island', 'South Carolina', 'South Dakota', 'Tennessee', 'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington']
# unitown Bellingham Washington
# unitown Cheney Washington
# unitown Ellensburg Washington
# unitown Pullman Washington
# unitown University District Washington
# state ['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California', 'Colorado', 'Connecticut', 'Delaware', 'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana', 'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland', 'Massachusetts', 'Michigan', 'Minnesota', 'Mississippi', 'Missouri', 'Montana', 'Nebraska', 'Nevada', 'New Hampshire', 'New Jersey', 'New Mexico', 'New York', 'North Carolina', 'North Dakota', 'Ohio', 'Oklahoma', 'Oregon', 'Pennsylvania', 'Rhode Island', 'South Carolina', 'South Dakota', 'Tennessee', 'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington', 'West Virginia']
# unitown Athens West Virginia
# unitown Buckhannon West Virginia
# unitown Fairmont West Virginia
# unitown Glenville West Virginia
# unitown Huntington West Virginia
# unitown Montgomery West Virginia
# unitown Morgantown West Virginia
# unitown Shepherdstown West Virginia
# unitown West Liberty West Virginia
# state ['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California', 'Colorado', 'Connecticut', 'Delaware', 'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana', 'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland', 'Massachusetts', 'Michigan', 'Minnesota', 'Mississippi', 'Missouri', 'Montana', 'Nebraska', 'Nevada', 'New Hampshire', 'New Jersey', 'New Mexico', 'New York', 'North Carolina', 'North Dakota', 'Ohio', 'Oklahoma', 'Oregon', 'Pennsylvania', 'Rhode Island', 'South Carolina', 'South Dakota', 'Tennessee', 'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington', 'West Virginia', 'Wisconsin']
# unitown Appleton Wisconsin
# unitown Eau Claire Wisconsin
# unitown Green Bay Wisconsin
# unitown La Crosse Wisconsin
# unitown Madison Wisconsin
# unitown Menomonie Wisconsin
# unitown Milwaukee Wisconsin
# unitown Oshkosh Wisconsin
# unitown Platteville Wisconsin
# unitown River Falls Wisconsin
# unitown Stevens Point Wisconsin
# unitown Waukesha Wisconsin
# unitown Whitewater Wisconsin
# state ['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California', 'Colorado', 'Connecticut', 'Delaware', 'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana', 'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland', 'Massachusetts', 'Michigan', 'Minnesota', 'Mississippi', 'Missouri', 'Montana', 'Nebraska', 'Nevada', 'New Hampshire', 'New Jersey', 'New Mexico', 'New York', 'North Carolina', 'North Dakota', 'Ohio', 'Oklahoma', 'Oregon', 'Pennsylvania', 'Rhode Island', 'South Carolina', 'South Dakota', 'Tennessee', 'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington', 'West Virginia', 'Wisconsin', 'Wyoming']
# unitown Laramie Wyoming

# %%
for i in df.index:
    if <something>:
        df.at[i, 'ifor'] = x
    else:
        df.at[i, 'ifor'] = y

# %%
for row in df.itertuples():
    if <something>:
        df.at[row.Index, 'ifor'] = x
    else:
        df.at[row.Index, 'ifor'] = x

    df.loc[row.Index, 'ifor'] = x

# %%
if "[edit]" in s :
        state = s.replace(r"\s*\[.*\]\s*","")
        i['State'] = state
    else :
        i['State'] = state
answer = uni
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-466eef273f12> in <module>
#       4     if "[edit]" in s :
#       5         state = s.replace(r"\s*\[.*\]\s*","")
# ----> 6         i['State'] = state
#       7     else :
#       8         i['State'] = state
#
# TypeError: 'Pandas' object does not support item assignment

# %%
    return answer
answer = get_list_of_university_towns()
print(type(answer))
print(answer)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-91fa2f194278> in <module>
#      23     answer = uni
#      24     return answer
# ---> 25 answer = get_list_of_university_towns()
#      26 print(type(answer))
#      27 print(answer)
#
# <ipython-input-26-91fa2f194278> in get_list_of_university_towns()
#      18         if "[edit]" in s :
#      19             state = s.replace(r"\s*\[.*\]\s*","")
# ---> 20             i['State'] = state
#      21         else :
#      22             i['State'] = state
#
# TypeError: 'Pandas' object does not support item assignment

# %%
def get_recession_start():
    '''Returns the year and quarter of the recession start time as a 
    string value in a format such as 2005q3'''
    
    return "ANSWER"

# %%
def get_recession_end():
    '''Returns the year and quarter of the recession end time as a 
    string value in a format such as 2005q3'''
       
    return "ANSWER"

# %%
def get_recession_bottom():
    '''Returns the year and quarter of the recession bottom time as a 
    string value in a format such as 2005q3'''
    
    return "ANSWER"

# %%
def convert_housing_data_to_quarters():
    '''Converts the housing data to quarters and returns it as mean 
    values in a dataframe. This dataframe should be a dataframe with
    columns for 2000q1 through 2016q3, and should have a multi-index
    in the shape of ["State","RegionName"].
    
    Note: Quarters are defined in the assignment description, they are
    not arbitrary three month periods.
    
    The resulting dataframe should have 67 columns, and 10,730 rows.
    '''
    
    return "ANSWER"

# %%
def run_ttest():
    '''First creates new data showing the decline or growth of housing prices
    between the recession start and the recession bottom. Then runs a ttest
    comparing the university town values to the non-university towns values, 
    return whether the alternative hypothesis (that the two groups are the same)
    is true or not as well as the p-value of the confidence. 
    
    Return the tuple (different, p, better) where different=True if the t-test is
    True at a p<0.01 (we reject the null hypothesis), or different=False if 
    otherwise (we cannot reject the null hypothesis). The variable p should
    be equal to the exact p value returned from scipy.stats.ttest_ind(). The
    value for better should be either "university town" or "non-university town"
    depending on which has a lower mean price ratio (which is equivilent to a
    reduced market loss).'''
    
    return "ANSWER"
